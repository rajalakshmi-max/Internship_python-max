# %%
# List

name = ["raji", "aarthi", "sakthi"]
name.append("kala")

marks = [78, 90, 80]

print(name)
print(marks[2])

print(len(name))
print(len(marks))
# Out:
# ['raji', 'aarthi', 'sakthi', 'kala']
# 80
# 4
# 3

# %%
# Tuple

days = ("Monday", "Tuesday", "Wednesday", "Thrusday","Friday" ,"Saturday")
print(days[4])
# Out:
# Friday

# %%
# Dictionary

student = {
    "name": "aarthi",
    "age": 21
}
