# %%
import numpy as np

marks = np.array([80, 99, 30, 20])

print(marks.sum())
# Out:
# 229

# %%
import numpy as np

arr = np.array([1, 3, 3])

print(arr)
print(arr[0])
print(arr[1])
print(arr[2])
# Out:
# [1 3 3]
# 1
# 3
# 3

# %%
import numpy as np

a = np.array([1, 8, 5])
b = np.array([5, 1, 9])

print(a + b)
# Out:
# [ 6  9 14]

# %%
import numpy as np

a = np.array([10, 20, 30])
b = np.array([5, 10, 15])

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
# Out:
# Addition: [15 30 45]
# Subtraction: [ 5 10 15]
# Multiplication: [ 50 200 450]
